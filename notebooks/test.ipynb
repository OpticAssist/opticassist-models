# %% [markdown]
# This is a test of YOLO models

# %%
from ultralytics import YOLO

# Load a pretrained YOLO model (recommended for training)
model = YOLO("yolo26n.pt")

# Train the model using the 'coco8.yaml' dataset for 3 epochs
results = model.train(data="coco8.yaml", epochs=3)

# Evaluate the model's performance on the validation set
results = model.val()

# Perform object detection on an image using the model
results = model("https://ultralytics.com/images/bus.jpg")

# Export the model to ONNX format
success = model.export(format="onnx")
# Out:
# WARNING ⚠️ Download failure, retrying 1/3 https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt... <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1028)>
# ######################################################################## 100.0%
# Ultralytics 8.4.50 🚀 Python-3.13.5 torch-2.12.0 CPU (Apple M1)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=coco8.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=3, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/Users/miguetaveras/Documents/GitHub/opticassist-models/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
# WARNING ⚠️ Dataset 'coco8.yaml' images not found, missing path '/Users/miguetaveras/Documents/GitHub/datasets/coco8/images/val'
# WARNING ⚠️ Download failure, retrying 1/3 https://ultralytics.com/assets/coco8.zip... <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1028)>
# Unzipping /Users/miguetaveras/Documents/GitHub/datasets/coco8.zip to /Users/miguetaveras/Documents/GitHub/datasets/coco8...: 100% ━━━━━━━━━━━━ 25/25 3.5Kfiles/s 0.0s
# Dataset download success ✅ (0.3s), saved to /Users/miguetaveras/Documents/GitHub/datasets
# ######################################################################## 100.0%
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    309656  ultralytics.nn.modules.head.Detect           [80, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,572,280 parameters, 2,572,280 gradients, 6.1 GFLOPs
#
# Transferred 708/708 items from pretrained weights
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 206.0±72.8 MB/s, size: 50.0 KB)
# train: Scanning /Users/miguetaveras/Documents/GitHub/datasets/coco8/labels/train... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 478.2it/s 0.0s
# train: New cache created: /Users/miguetaveras/Documents/GitHub/datasets/coco8/labels/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 202.0±73.7 MB/s, size: 54.0 KB)
# val: Scanning /Users/miguetaveras/Documents/GitHub/datasets/coco8/labels/val... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 2.2Kit/s 0.0s
# val: New cache created: /Users/miguetaveras/Documents/GitHub/datasets/coco8/labels/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000119, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to /Users/miguetaveras/Documents/GitHub/opticassist-models/runs/detect/train/labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /Users/miguetaveras/Documents/GitHub/opticassist-models/runs/detect/train
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/3         0G     0.9632      2.291    0.01334         30        640: 100% ━━━━━━━━━━━━ 1/1 2.4s/it 2.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.8it/s 0.5s
#                    all          4         17      0.897      0.656      0.904      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/3         0G      1.169      2.443    0.01394         30        640: 100% ━━━━━━━━━━━━ 1/1 1.9s/it 1.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all          4         17      0.897      0.658      0.902      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/3         0G     0.9839      2.767    0.02108         16        640: 100% ━━━━━━━━━━━━ 1/1 1.9s/it 1.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all          4         17      0.873      0.671      0.906      0.666
#
# 3 epochs completed in 0.002 hours.
# Optimizer stripped from /Users/miguetaveras/Documents/GitHub/opticassist-models/runs/detect/train/weights/last.pt, 5.5MB
# Optimizer stripped from /Users/miguetaveras/Documents/GitHub/opticassist-models/runs/detect/train/weights/best.pt, 5.5MB
#
# Validating /Users/miguetaveras/Documents/GitHub/opticassist-models/runs/detect/train/weights/best.pt...
# Ultralytics 8.4.50 🚀 Python-3.13.5 torch-2.12.0 CPU (Apple M1)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.9it/s 0.5s
#                    all          4         17      0.898      0.655      0.904      0.667
#                 person          3         10          1      0.432      0.781      0.391
#                    dog          1          1      0.729          1      0.995      0.597
#                  horse          1          2      0.814          1      0.995      0.795
#               elephant          1          2      0.842        0.5      0.662      0.427
#               umbrella          1          1          1          1      0.995      0.895
#           potted plant          1          1          1          0      0.995      0.895
# Speed: 0.5ms preprocess, 126.8ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /Users/miguetaveras/Documents/GitHub/opticassist-models/runs/detect/train
# Ultralytics 8.4.50 🚀 Python-3.13.5 torch-2.12.0 CPU (Apple M1)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 849.9±443.9 MB/s, size: 54.0 KB)
# val: Scanning /Users/miguetaveras/Documents/GitHub/datasets/coco8/labels/val.cache... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 1.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.0it/s 0.2s
#                    all          4         17      0.898      0.655      0.904      0.667
#                 person          3         10          1      0.432      0.781      0.391
#                    dog          1          1      0.729          1      0.995      0.597
#                  horse          1          2      0.814          1      0.995      0.795
#               elephant          1          2      0.842        0.5      0.662      0.427
#               umbrella          1          1          1          1      0.995      0.895
#           potted plant          1          1          1          0      0.995      0.895
# Speed: 0.5ms preprocess, 57.8ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /Users/miguetaveras/Documents/GitHub/opticassist-models/runs/detect/val
#
# WARNING ⚠️ Download failure, retrying 1/3 https://ultralytics.com/images/bus.jpg... <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1028)>
# #O#-#
# image 1/1 /Users/miguetaveras/Documents/GitHub/opticassist-models/notebooks/bus.jpg: 640x480 4 persons, 1 bus, 54.9ms
# Speed: 4.0ms preprocess, 54.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# Ultralytics 8.4.50 🚀 Python-3.13.5 torch-2.12.0 CPU (Apple M1)
# ######################################################################## 100.0%
# PyTorch: starting from '/Users/miguetaveras/Documents/GitHub/opticassist-models/runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 300, 6) (5.3 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<2.0.0', 'onnxslim>=0.1.71', 'onnxruntime'] not found, attempting AutoUpdate...
# Collecting onnx<2.0.0,>=1.12.0
#   Downloading onnx-1.21.0-cp312-abi3-macosx_12_0_universal2.whl.metadata (8.5 kB)
# Collecting onnxslim>=0.1.71
#   Downloading onnxslim-0.1.93-py3-none-any.whl.metadata (10 kB)
# Collecting onnxruntime
#   Downloading onnxruntime-1.26.0-cp313-cp313-macosx_14_0_arm64.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy>=1.23.2 in /Users/miguetaveras/Documents/GitHub/opticassist-models/.venv/lib/python3.13/site-packages (from onnx<2.0.0,>=1.12.0) (2.4.4)
# Requirement already satisfied: protobuf>=4.25.1 in /Users/miguetaveras/Documents/GitHub/opticassist-models/.venv/lib/python3.13/site-packages (from onnx<2.0.0,>=1.12.0) (7.34.1)
# Requirement already satisfied: typing_extensions>=4.7.1 in /Users/miguetaveras/Documents/GitHub/opticassist-models/.venv/lib/python3.13/site-packages (from onnx<2.0.0,>=1.12.0) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /Users/miguetaveras/Documents/GitHub/opticassist-models/.venv/lib/python3.13/site-packages (from onnx<2.0.0,>=1.12.0) (0.5.4)
# Collecting colorama (from onnxslim>=0.1.71)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: packaging in /Users/miguetaveras/Documents/GitHub/opticassist-models/.venv/lib/python3.13/site-packages (from onnxslim>=0.1.71) (26.2)
# Requirement already satisfied: sympy>=1.13.1 in /Users/miguetaveras/Documents/GitHub/opticassist-models/.venv/lib/python3.13/site-packages (from onnxslim>=0.1.71) (1.14.0)
# Requirement already satisfied: flatbuffers in /Users/miguetaveras/Documents/GitHub/opticassist-models/.venv/lib/python3.13/site-packages (from onnxruntime) (25.12.19)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/miguetaveras/Documents/GitHub/opticassist-models/.venv/lib/python3.13/site-packages (from sympy>=1.13.1->onnxslim>=0.1.71) (1.3.0)
# Downloading onnx-1.21.0-cp312-abi3-macosx_12_0_universal2.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/18.0 MB ? eta -:--:--
#    ━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/18.0 MB 8.1 MB/s eta 0:00:03
#    ━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/18.0 MB 9.6 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/18.0 MB 10.6 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━ 7.9/18.0 MB 9.8 MB/s eta 0:00:02
#    ━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━ 10.7/18.0 MB 10.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━ 12.6/18.0 MB 10.3 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━ 14.4/18.0 MB 10.1 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━ 16.3/18.0 MB 10.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 9.8 MB/s eta 0:00:00
# Downloading onnxslim-0.1.93-py3-none-any.whl (238 kB)
# Downloading onnxruntime-1.26.0-cp313-cp313-macosx_14_0_arm64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/18.0 MB ? eta -:--:--
#    ━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/18.0 MB 16.1 MB/s eta 0:00:01
#    ━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/18.0 MB 13.3 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 9.2/18.0 MB 15.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 13.6/18.0 MB 16.7 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━ 16.3/18.0 MB 15.8 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 16.3 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: onnxruntime, colorama, onnx, onnxslim
#
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/4 [onnxruntime]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/4 [onnxruntime]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/4 [onnxruntime]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/4 [onnxruntime]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/4 [onnxruntime]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 2/4 [onnx]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [onnxslim]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 3/4 [onnxslim]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [onnxslim]
#
# Successfully installed colorama-0.4.6 onnx-1.21.0 onnxruntime-1.26.0 onnxslim-0.1.93
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
#
# requirements: AutoUpdate success ✅ 10.1s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.21.0 opset 20...
# ONNX: slimming with onnxslim 0.1.93...
# /Users/miguetaveras/Documents/GitHub/opticassist-models/.venv/lib/python3.13/site-packages/torch/onnx/_internal/torchscript_exporter/symbolic_opset11.py:954: UserWarning: Exporting aten::index operator of advanced indexing in opset 20 is achieved by combination of multiple ONNX operators, including Reshape, Transpose, Concat, and Gather. If indices include negative values, the exported graph will produce incorrect results.
#   return opset9.index(g, self, index)
# ONNX: export success ✅ 13.4s, saved as '/Users/miguetaveras/Documents/GitHub/opticassist-models/runs/detect/train/weights/best.onnx' (9.5 MB)
#
# Export complete (13.6s)
# Results saved to /Users/miguetaveras/Documents/GitHub/opticassist-models/runs/detect/train/weights/best.onnx
# Predict:         yolo predict task=detect model=/Users/miguetaveras/Documents/GitHub/opticassist-models/runs/detect/train/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=/Users/miguetaveras/Documents/GitHub/opticassist-models/runs/detect/train/weights/best.onnx imgsz=640 data=/Users/miguetaveras/Documents/GitHub/opticassist-models/.venv/lib/python3.13/site-packages/ultralytics/cfg/datasets/coco8.yaml
# Visualize:       https://netron.app
